# %%
# !pip install transformers torch sklearn

import torch
from torch.utils.data import DataLoader, Dataset
from transformers import BertTokenizer, BertForSequenceClassification, AdamW, get_linear_schedule_with_warmup
import pandas as pd
from sklearn.metrics import accuracy_score
import numpy as np
from sklearn.model_selection import train_test_split

# Helper function to load data
def load_data(file_path):
    return pd.read_csv(file_path, delimiter=';', header=None, names=['text', 'label'])

# Load data
train_data = load_data('/content/train.txt')
val_data = load_data('/content/val.txt')
test_data = load_data('/content/test.txt')

# Initialize tokenizer
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# Dataset class
class EmotionDataset(Dataset):
    def __init__(self, texts, labels, tokenizer, max_len):
        self.texts = texts
        self.labels = labels
        self.tokenizer = tokenizer
        self.max_len = max_len

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, index):
        text = str(self.texts[index])
        label = self.labels[index]

        encoding = self.tokenizer.encode_plus(
            text,
            add_special_tokens=True,
            max_length=self.max_len,
            return_token_type_ids=False,
            padding='max_length',
            return_attention_mask=True,
            return_tensors='pt',
            truncation=True
        )

        return {
            'input_ids': encoding['input_ids'].flatten(),
            'attention_mask': encoding['attention_mask'].flatten(),
            'labels': torch.tensor(label, dtype=torch.long)
        }

# Convert labels to categorical values
label_dict = {}
for index, label in enumerate(train_data['label'].unique()):
    label_dict[label] = index

train_data['label'] = train_data['label'].replace(label_dict)
val_data['label'] = val_data['label'].replace(label_dict)
test_data['label'] = test_data['label'].replace(label_dict)

# Data loaders
def create_data_loader(df, tokenizer, max_len, batch_size):
    ds = EmotionDataset(
        texts=df.text.to_numpy(),
        labels=df.label.to_numpy(),
        tokenizer=tokenizer,
        max_len=max_len
    )

    return DataLoader(ds, batch_size=batch_size, num_workers=2)

# Parameters
batch_size = 16
max_len = 256

train_loader = create_data_loader(train_data, tokenizer, max_len, batch_size)
val_loader = create_data_loader(val_data, tokenizer, max_len, batch_size)
test_loader = create_data_loader(test_data, tokenizer, max_len, batch_size)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Load BERT with a classification head
model = BertForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=len(label_dict))
model = model.to(device)
optimizer = AdamW(model.parameters(), lr=2e-5, correct_bias=False)

# Train and evaluate the model
# Include training loop, evaluation, and save the model
# This section will be lengthy and involve setting up the training epochs, handling GPU acceleration, etc.
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.38.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.2.1+cu121)
# Collecting sklearn
#   Downloading sklearn-0.0.post12.tar.gz (2.6 kB)
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:429: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(

# %%
from transformers import get_linear_schedule_with_warmup
import torch.nn.functional as F

# Define training parameters
epochs = 4
total_steps = len(train_loader) * epochs

# Setup the optimizer and the learning rate scheduler
optimizer = AdamW(model.parameters(), lr=2e-5, correct_bias=False)
scheduler = get_linear_schedule_with_warmup(
    optimizer,
    num_warmup_steps=0,
    num_training_steps=total_steps
)

# Move model to GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

# Function to train the model for one epoch
def train_epoch(model, data_loader, optimizer, device, scheduler):
    model.train()
    total_train_loss = 0
    total_train_accuracy = 0

    for step, batch in enumerate(data_loader):
        batch_input_ids = batch['input_ids'].to(device)
        batch_attention_mask = batch['attention_mask'].to(device)
        batch_labels = batch['labels'].to(device)

        model.zero_grad()
        outputs = model(batch_input_ids, attention_mask=batch_attention_mask, labels=batch_labels)

        loss = outputs.loss
        logits = outputs.logits
        total_train_loss += loss.item()

        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()
        scheduler.step()

        preds = torch.argmax(F.softmax(logits, dim=1), dim=1)
        total_train_accuracy += torch.sum(preds == batch_labels)

    average_train_loss = total_train_loss / len(data_loader)
    average_train_accuracy = total_train_accuracy.double() / (len(data_loader) * data_loader.batch_size)
    return average_train_loss, average_train_accuracy

# Function for evaluating the model
def eval_model(model, data_loader, device):
    model.eval()
    total_eval_accuracy = 0
    total_eval_loss = 0

    for batch in data_loader:
        batch_input_ids = batch['input_ids'].to(device)
        batch_attention_mask = batch['attention_mask'].to(device)
        batch_labels = batch['labels'].to(device)

        with torch.no_grad():
            outputs = model(batch_input_ids, attention_mask=batch_attention_mask, labels=batch_labels)

        loss = outputs.loss
        logits = outputs.logits
        total_eval_loss += loss.item()

        preds = torch.argmax(F.softmax(logits, dim=1), dim=1)
        total_eval_accuracy += torch.sum(preds == batch_labels)

    average_eval_loss = total_eval_loss / len(data_loader)
    average_eval_accuracy = total_eval_accuracy.double() / (len(data_loader) * data_loader.batch_size)
    return average_eval_loss, average_eval_accuracy

# Training and evaluation loop
for epoch in range(epochs):
    train_loss, train_accuracy = train_epoch(model, train_loader, optimizer, device, scheduler)
    print(f"Epoch {epoch + 1} | Train Loss: {train_loss} | Train Accuracy: {train_accuracy}")

    val_loss, val_accuracy = eval_model(model, val_loader, device)
    print(f"Epoch {epoch + 1} | Val Loss: {val_loss} | Val Accuracy: {val_accuracy}")

# Save the model
model_path = "/content/drive/MyDrive/model_save"
model.save_pretrained(model_path)
tokenizer.save_pretrained(model_path)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:429: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# Epoch 1 | Train Loss: 0.4084482608414255 | Train Accuracy: 0.8572500000000001
# Epoch 1 | Val Loss: 0.19104178422875703 | Val Accuracy: 0.9345
# Epoch 2 | Train Loss: 0.13216075107152575 | Train Accuracy: 0.9454375
# Epoch 2 | Val Loss: 0.1788256106246263 | Val Accuracy: 0.9425
# Epoch 3 | Train Loss: 0.09278312066517537 | Train Accuracy: 0.962125
# Epoch 3 | Val Loss: 0.19652077536517754 | Val Accuracy: 0.9390000000000001
# Epoch 4 | Train Loss: 0.06897374678234337 | Train Accuracy: 0.971875
# Epoch 4 | Val Loss: 0.2089117198032327 | Val Accuracy: 0.9400000000000001
# ('/content/drive/MyDrive/model_save/tokenizer_config.json',
#  '/content/drive/MyDrive/model_save/special_tokens_map.json',
#  '/content/drive/MyDrive/model_save/vocab.txt',
#  '/content/drive/MyDrive/model_save/added_tokens.json')

# %%
from flask import Flask, request, jsonify
import torch
from transformers import BertTokenizer, BertForSequenceClassification
import torch.nn.functional as F

app = Flask(__name__)

# Load the model and tokenizer
model_path = 'path_to_saved_model'
model = BertForSequenceClassification.from_pretrained(model_path)
tokenizer = BertTokenizer.from_pretrained(model_path)
model.eval()

# Define prediction function
def predict_emotion(text):
    inputs = tokenizer(text, padding=True, truncation=True, max_length=512, return_tensors="pt")
    with torch.no_grad():
        outputs = model(**inputs)
    probs = F.softmax(outputs.logits, dim=1)
    return probs.numpy().flatten()

# Define a route to handle web requests
@app.route('/predict', methods=['POST'])
def predict():
    text_data = request.json['text']
    probs = predict_emotion(text_data)
    emotion_labels = ['anger', 'joy', 'sadness', 'fear', ...]  # Adjust based on your model
    overall_emotion = emotion_labels[np.argmax(probs)]
    emotion_distribution = dict(zip(emotion_labels, probs.tolist()))
    return jsonify(overall_emotion=overall_emotion, distribution=emotion_distribution)

if __name__ == '__main__':
    app.run(debug=True)

# %%
import torch
from transformers import BertTokenizer, BertForSequenceClassification
import torch.nn.functional as F

# Load the trained model and tokenizer
model_path = '/content/drive/MyDrive/model_save'
model = BertForSequenceClassification.from_pretrained(model_path)
tokenizer = BertTokenizer.from_pretrained(model_path)
model.eval()
model.to('cuda' if torch.cuda.is_available() else 'cpu')

def predict_emotion(input_data):
    # Check if the input data is a filepath
    if isinstance(input_data, str) and input_data.endswith('.txt'):
        with open(input_data, 'r', encoding='utf-8') as file:
            text = file.read()
    else:
        text = input_data

    # Encode and prepare input data
    inputs = tokenizer(text, return_tensors="pt", padding=True, truncation=True, max_length=512)
    input_ids = inputs['input_ids'].to('cuda' if torch.cuda.is_available() else 'cpu')
    attention_mask = inputs['attention_mask'].to('cuda' if torch.cuda.is_available() else 'cpu')

    # Prediction
    with torch.no_grad():
        outputs = model(input_ids, attention_mask=attention_mask)
        probabilities = F.softmax(outputs.logits, dim=1)
        probs = probabilities.squeeze().tolist()

    # Decode predictions
    emotions = tokenizer.ids_to_labels.keys()  # Ensure you have this mapping saved from training time
    emotion_probs = dict(zip(emotions, probs))
    overall_emotion = max(emotion_probs, key=emotion_probs.get)

    return overall_emotion, emotion_probs

# Example usage
text_input = "I'm feeling very happy today! It's a good day."
overall_emotion, emotion_distribution = predict_emotion(text_input)

# If you want to test with a file
# overall_emotion, emotion_distribution = predict_emotion('path_to_your_file.txt')

print("Overall Emotion:", overall_emotion)
print("Emotion Distribution:", emotion_distribution)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-47cf1420efc6> in <cell line: 40>()
#      38 # Example usage
#      39 text_input = "I'm feeling very happy today! It's a good day."
# ---> 40 overall_emotion, emotion_distribution = predict_emotion(text_input)
#      41
#      42 # If you want to test with a file
#
# <ipython-input-3-47cf1420efc6> in predict_emotion(input_data)
#      30
#      31     # Decode predictions
# ---> 32     emotions = tokenizer.ids_to_labels.keys()  # Ensure you have this mapping saved from training time
#      33     emotion_probs = dict(zip(emotions, probs))
#      34     overall_emotion = max(emotion_probs, key=emotion_probs.get)
#
# AttributeError: 'BertTokenizer' object has no attribute 'ids_to_labels'

# %%
label_dict = {
    'sadness': 0,
    'anger': 1,
    'love': 2,
    'surprise': 3,
    'fear': 4,
    'joy': 5
}

# Reverse the dictionary for mapping numeric IDs back to labels
id_to_label = {v: k for k, v in label_dict.items()}

# %%
import torch
from transformers import BertTokenizer, BertForSequenceClassification
import torch.nn.functional as F

# Load the model and tokenizer
model_path = 'model_save'
model = BertForSequenceClassification.from_pretrained(model_path)
tokenizer = BertTokenizer.from_pretrained(model_path)
model.eval()
model.to(torch.device("cuda" if torch.cuda.is_available() else "cpu"))

def predict_emotion(input_data):
    if isinstance(input_data, str) and input_data.endswith('.txt'):
        with open(input_data, 'r', encoding='utf-8') as file:
            text = file.read()
    else:
        text = input_data

    # Encode and prepare input data
    inputs = tokenizer(text, return_tensors="pt", padding=True, truncation=True, max_length=512)
    input_ids = inputs['input_ids'].to(torch.device("cuda" if torch.cuda.is_available() else "cpu"))
    attention_mask = inputs['attention_mask'].to(torch.device("cuda" if torch.cuda.is_available() else "cpu"))

    # Make prediction
    with torch.no_grad():
        outputs = model(input_ids, attention_mask=attention_mask)
        probabilities = F.softmax(outputs.logits, dim=1)
        probs = probabilities.squeeze().tolist()

    # Determine the most likely emotion
    predicted_index = torch.argmax(outputs.logits, dim=1).item()
    overall_emotion = id_to_label[predicted_index]
    emotion_distribution = {id_to_label[i]: prob for i, prob in enumerate(probs)}

    return overall_emotion, emotion_distribution

# Example usage
text_input = "I'm feeling very happy today! It's a good day."
overall_emotion, emotion_distribution = predict_emotion(text_input)
print("Overall Emotion:", overall_emotion)
print("Emotion Distribution:", emotion_distribution)
# Out:
# Overall Emotion: joy
# Emotion Distribution: {'sadness': 7.412652485072613e-05, 'anger': 4.435436494532041e-05, 'love': 0.0001445561065338552, 'surprise': 7.244136213557795e-05, 'fear': 4.1335875721415505e-05, 'joy': 0.99962317943573}

# %%
import pandas as pd

def test_model(test_file_path, model, tokenizer):
    # Load the test data
    test_data = pd.read_csv(test_file_path, delimiter=';', header=None, names=['text', 'true_label'])

    # Prepare to collect predictions
    predictions = []
    true_labels = []
    emotion_distributions = []

    for index, row in test_data.iterrows():
        text = row['text']
        true_label = row['true_label']
        predicted_emotion, emotion_distribution = predict_emotion(text)

        # Store results
        predictions.append(predicted_emotion)
        true_labels.append(true_label)
        emotion_distributions.append(emotion_distribution)

        # Print the results for each text
        print(f"Text: {text}")
        print(f"Predicted Emotion: {predicted_emotion}")
        print(f"Emotion Distribution: {emotion_distribution}\n")

    # Calculate accuracy if true labels are available and labels are in `label_dict`
    if all(label in label_dict for label in true_labels):
        accuracy = sum(1 for i in range(len(predictions)) if predictions[i] == true_labels[i]) / len(predictions)
        print(f"Accuracy: {accuracy * 100:.2f}%")

# Example usage, assuming the paths and model are correctly set up
test_file_path = '/content/test.txt'
test_model(test_file_path, model, tokenizer)
# Out:
# Streaming output truncated to the last 5000 lines.
# Predicted Emotion: sadness
# Emotion Distribution: {'sadness': 0.9996460676193237, 'anger': 0.0001283595192944631, 'love': 4.2530311475275084e-05, 'surprise': 6.782468699384481e-05, 'fear': 6.29233181825839e-05, 'joy': 5.228963709669188e-05}
#
# Text: i enjoy about his work is the genuine feel and the pleasant message he is trying to deliver with all this
# Predicted Emotion: joy
# Emotion Distribution: {'sadness': 6.830722850281745e-05, 'anger': 3.7669022276531905e-05, 'love': 0.0001331923995167017, 'surprise': 7.502189691876993e-05, 'fear': 4.4531865569297224e-05, 'joy': 0.9996411800384521}
#
# Text: i knew except they ve lost that girly feeling and gained a graceful wisdom
# Predicted Emotion: joy
# Emotion Distribution: {'sadness': 9.224736277246848e-05, 'anger': 4.6016983105801046e-05, 'love': 0.0001185972651001066, 'surprise': 9.385620069224387e-05, 'fear': 4.9984078941633925e-05, 'joy': 0.999599277973175}
#
# Text: i am feeling a bit ungrateful and choose to correct that
# Predicted Emotion: sadness
# Emotion Distribution: {'sadness': 0.9996641874313354, 'anger': 9.3915565230418e-05, 'love': 6.524055061163381e-05, 'surprise': 6.643390952376649e-05, 'fear': 4.518795685726218e-05, 'joy': 6.510057573905215e-05}
#
# Text: i notice how different this question is from why i am feeling so agitated
# Predicted Emotion: fear
# Emotion Distribution: {'sadness': 0.0005804441752843559, 'anger': 0.05906965956091881, 'love': 0.00025542042567394674, 'surprise': 0.0006027978961355984, 'fear': 0.9391824007034302, 'joy': 0.00030940878787077963}
#
# Text: i feel like such a noob when the customers make really dull and stupid jokes that im supposed to find funny
# Predicted Emotion: sadness
# Emotion Distribution: {'sadness': 0.9996100068092346, 'anger': 0.0001277234696317464, 'love': 6.662191299255937e-05, 'surprise': 8.29672790132463e-05, 'fear': 3.903925608028658e-05, 'joy': 7.36414804123342e-05}
#
# Text: getting sent on a company expense trip to another state to work for a week at that plan
# Predicted Emotion: joy
# Emotion Distribution: {'sadness': 0.041141729801893234, 'anger': 0.24726156890392303, 'love': 0.002040708437561989, 'surprise': 0.004391398746520281, 'fear': 0.11052880436182022, 'joy': 0.5946358442306519}
#
# Text: i feel insulted by how those heroes of cosplay goons said they don t care if you re if
# Predicted Emotion: anger
# Emotion Distribution: {'sadness': 0.00011632134555839002, 'anger': 0.9993436932563782, 'love': 0.00015569021343253553, 'surprise': 0.00018414025544188917, 'fear': 0.00012053913087584078, 'joy': 7.955737964948639e-05}
#
# Text: i eat a good breakfast i feel more energetic throughout the whole day and don t feel that o clock slump
# Predicted Emotion: joy
# Emotion Distribution: {'sadness': 8.031749894144014e-05, 'anger': 4.59151815448422e-05, 'love': 0.00011320417252136394, 'surprise': 7.089529390214011e-05, 'fear': 4.3953274143859744e-05, 'joy': 0.9996457099914551}
#
# Text: i feel very strongly about supporting charities that help children
# Predicted Emotion: love
# Emotion Distribution: {'sadness': 0.0002779546193778515, 'anger': 0.0005504688015207648, 'love': 0.9012032747268677, 'surprise': 0.00042373014730401337, 'fear': 0.00026632516528479755, 'joy': 0.09727830439805984}
#
# Text: i have ever seen in my life was laceys constant disapprovements of rikkis extreme happiness when she just wasnt feeling quite as carefree as he was
# Predicted Emotion: joy
# Emotion Distribution: {'sadness': 8.406232518609613e-05, 'anger': 5.01535578223411e-05, 'love': 9.925197809934616e-05, 'surprise': 8.454680937575176e-05, 'fear': 4.904420711682178e-05, 'joy': 0.9996329545974731}
#
# Text: i started thinking about which spaces made me feel most creative and what characteristics they had
# Predicted Emotion: joy
# Emotion Distribution: {'sadness': 6.619523628614843e-05, 'anger': 5.1140497816959396e-05, 'love': 0.00011558191908989102, 'surprise': 7.844567880965769e-05, 'fear': 4.548954893834889e-05, 'joy': 0.9996432065963745}
#
# Text: i usually ignore page invites that are irrelevant to me or facebook game invites because its impersonal and it feels insincere
# Predicted Emotion: anger
# Emotion Distribution: {'sadness': 8.709728717803955e-05, 'anger': 0.9991745352745056, 'love': 0.00016964318638201803, 'surprise': 0.0001709818752715364, 'fear': 0.00034034205600619316, 'joy': 5.742374560213648e-05}
#
# Text: i am feeling playful this morning
# Predicted Emotion: joy
# Emotion Distribution: {'sadness': 6.683270476059988e-05, 'anger': 5.437275467556901e-05, 'love': 0.000113800706458278, 'surprise': 8.974876982392743e-05, 'fear': 5.155475082574412e-05, 'joy': 0.9996237754821777}
#
# Text: i feel like im a pathetic little desperation
# Predicted Emotion: sadness
# Emotion Distribution: {'sadness': 0.9996790885925293, 'anger': 0.00010184726124862209, 'love': 5.234519994701259e-05, 'surprise': 6.0508471506182104e-05, 'fear': 6.292881153058261e-05, 'joy': 4.333944889367558e-05}
#
# Text: i feel totally completely accepted and loved while my heavenly abba was pointing out sin in my life
# Predicted Emotion: joy
# Emotion Distribution: {'sadness': 0.00026674321270547807, 'anger': 0.0003118918975815177, 'love': 0.2962487041950226, 'surprise': 0.0005992071819491684, 'fear': 0.0002546194300521165, 'joy': 0.7023189067840576}
#
# Text: i feel fond of him though because he feels like an amalgamation of many people i already know
# Predicted Emotion: love
# Emotion Distribution: {'sadness': 0.00017852876044344157, 'anger': 0.000312440941343084, 'love': 0.9986270666122437, 'surprise': 0.00037415133556351066, 'fear': 0.0002578337152954191, 'joy': 0.0002498841204214841}
#
# Text: i feel like most teams would have appeased jackson at this point but the eagles are terribly stubborn
# Predicted Emotion: anger
# Emotion Distribution: {'sadness': 0.001169332186691463, 'anger': 0.8197338581085205, 'love': 0.003134786384180188, 'surprise': 0.0013229113537818193, 'fear': 0.00039211727562360466, 'joy': 0.17424698173999786}
#
# Text: i feel like damaged goods no one will want me now
# Predicted Emotion: sadness
# Emotion Distribution: {'sadness': 0.999659538269043, 'anger': 0.00011943676508963108, 'love': 5.9483096265466884e-05, 'surprise': 6.093616320868023e-05, 'fear': 4.6529239625670016e-05, 'joy': 5.4155683756107464e-05}
#
# Text: i think i love her enough now to feel pretty insulted and rawr about it
# Predicted Emotion: anger
# Emotion Distribution: {'sadness': 0.00012338333181105554, 'anger': 0.9993860721588135, 'love': 0.00015092134708538651, 'surprise': 0.00014192114758770913, 'fear': 0.00011742876085918397, 'joy': 8.023877308005467e-05}
#
# Text: i can t help feeling lucky little do i know
# Predicted Emotion: joy
# Emotion Distribution: {'sadness': 6.149856926640496e-05, 'anger': 3.434109385125339e-05, 'love': 0.0001565455022500828, 'surprise': 7.377927977358922e-05, 'fear': 3.5915545595344156e-05, 'joy': 0.9996379613876343}
#
# Text: i also feel the need to say thank you to the boy who helped me realize the above for showing me an absolutely splendid and hot night
# Predicted Emotion: joy
# Emotion Distribution: {'sadness': 5.1826416893163696e-05, 'anger': 3.553430724423379e-05, 'love': 0.00011855990305775777, 'surprise': 0.00011277507292106748, 'fear': 4.90846905449871e-05, 'joy': 0.9996322393417358}
#
# Text: i can never tell him how i feel and it really sucks because i think he gets really bothered by that
# Predicted Emotion: anger
# Emotion Distribution: {'sadness': 0.00014602353621739894, 'anger': 0.999321699142456, 'love': 0.00020405725808814168, 'surprise': 0.00015691995213273913, 'fear': 0.00010167918662773445, 'joy': 6.970908725634217e-05}
#
# Text: ive also had a nosy on the website and seeing as its coming up to that time of year and im feeling strangely festive for once ive picked my top five products from the a href http www
# Predicted Emotion: joy
# Emotion Distribution: {'sadness': 7.03001715010032e-05, 'anger': 4.5487613533623517e-05, 'love': 0.00011434461339376867, 'surprise': 8.278708992293105e-05, 'fear': 6.636617763433605e-05, 'joy': 0.9996206760406494}
#
# Text: i suppose its only natural that id start to feel a little homesick for new england at this time of year
# Predicted Emotion: sadness
# Emotion Distribution: {'sadness': 0.9995662569999695, 'anger': 0.00016140466323122382, 'love': 0.00013062075595371425, 'surprise': 6.245975237106904e-05, 'fear': 4.534593244898133e-05, 'joy': 3.390005076653324e-05}
#
# Text: i really feel like we were successful in identifying some pretty scary early warning signs and sticking our foot in the door before it shut
# Predicted Emotion: joy
# Emotion Distribution: {'sadness': 8.068086026469246e-05, 'anger': 5.160640648682602e-05, 'love': 9.57139054662548e-05, 'surprise': 8.926214650273323e-05, 'fear': 5.496937592397444e-05, 'joy': 0.9996277093887329}
#
# Text: i cant help but think if id just shut up if id just not made a big deal of what was essentially two adults meeting at the same table for a hot beverage then perhaps i wouldnt have spent the bulk of the weekend feeling like a stupid shit
# Predicted Emotion: sadness
# Emotion Distribution: {'sadness': 0.9995757937431335, 'anger': 0.0001523229293525219, 'love': 7.885132799856365e-05, 'surprise': 6.729605229338631e-05, 'fear': 4.161871038377285e-05, 'joy': 8.40859065647237e-05}
#
# Text: i have been feeling really stressed out due to homework and my studies that have increased rapidly over the last week
# Predicted Emotion: sadness
# Emotion Distribution: {'sadness': 0.8917935490608215, 'anger': 0.1051868200302124, 'love': 0.00038310137460939586, 'surprise': 0.0003542071208357811, 'fear': 0.001039123977534473, 'joy': 0.0012432156363502145}
#
# Text: im begging fate not to mess with the next cycle to let it look as pretty as this one so i can at least go in feeling reassured
# Predicted Emotion: joy
# Emotion Distribution: {'sadness': 5.8506877394393086e-05, 'anger': 3.864940663333982e-05, 'love': 0.00013128503633197397, 'surprise': 6.998024036874995e-05, 'fear': 6.28205671091564e-05, 'joy': 0.9996387958526611}
#
# Text: i input class size medium wp image height src http techfeel in wp content uploads google hindi input x
# Predicted Emotion: joy
# Emotion Distribution: {'sadness': 0.04415581375360489, 'anger': 0.3193969130516052, 'love': 0.0027335966005921364, 'surprise': 0.003234387841075659, 'fear': 0.024636197835206985, 'joy': 0.6058431267738342}
#
# Text: ive got to learn to be mindful of how i feel all the time not just if im suspicious of a feeling
# Predicted Emotion: fear
# Emotion Distribution: {'sadness': 0.00012711898307316005, 'anger': 0.00013357002171687782, 'love': 0.00019653979688882828, 'surprise': 0.00037491609691642225, 'fear': 0.9989861845970154, 'joy': 0.00018169697432313114}
#
# Text: i am feeling much more relaxed
# Predicted Emotion: joy
# Emotion Distribution: {'sadness': 5.94662778894417e-05, 'anger': 4.332800017436966e-05, 'love': 0.00012213247828185558, 'surprise': 8.372600859729573e-05, 'fear': 4.6448443754343316e-05, 'joy': 0.9996447563171387}
#
# Text: i feel it is acceptable to make requests using this name
# Predicted Emotion: joy
# Emotion Distribution: {'sadness': 7.001043559284881e-05, 'anger': 4.2965624743374065e-05, 'love': 0.0001300257572438568, 'surprise': 7.719633867964149e-05, 'fear': 4.896081372862682e-05, 'joy': 0.9996306896209717}
#
# Text: i have a feeling there are a lot of pissed off people in sea org in hollywood where scientology has become the monster that devoured wa wonderfully sleazy bohemian area
# Predicted Emotion: anger
# Emotion Distribution: {'sadness': 0.00012396597594488412, 'anger': 0.999373733997345, 'love': 0.00017704145284369588, 'surprise': 0.00013806844071950763, 'fear': 0.0001014478548313491, 'joy': 8.578540291637182e-05}
#
# Text: i feel pained by this
# Predicted Emotion: sadness
# Emotion Distribution: {'sadness': 0.9995214939117432, 'anger': 0.000177990339579992, 'love': 0.00012789535685442388, 'surprise': 6.775048677809536e-05, 'fear': 7.803211337886751e-05, 'joy': 2.682343802007381e-05}
#
# Text: i am reading about s sewing circles and i feel completely happy if you cant spit in the face of imperialism at least be a lesbian
# Predicted Emotion: joy
# Emotion Distribution: {'sadness': 7.277615077327937e-05, 'anger': 4.68447724415455e-05, 'love': 0.00011388106941012666, 'surprise': 7.654031651327386e-05, 'fear': 4.402741615194827e-05, 'joy': 0.9996459484100342}
#
# Text: i am feeling pretty fearless
# Predicted Emotion: joy
# Emotion Distribution: {'sadness': 5.476680235005915e-05, 'anger': 4.644165528588928e-05, 'love': 0.00010792395914904773, 'surprise': 9.815780504141003e-05, 'fear': 6.721569661749527e-05, 'joy': 0.9996254444122314}
#
# Text: i feel bouncy and twitchy all of a sudden
# Predicted Emotion: joy
# Emotion Distribution: {'sadness': 5.331982538336888e-05, 'anger': 4.4104519474785775e-05, 'love': 0.00014245709462556988, 'surprise': 0.00010276243119733408, 'fear': 5.6469962146366015e-05, 'joy': 0.9996009469032288}
#
# Text: i feel like it s more of a mellow restive dream maker
# Predicted Emotion: joy
# Emotion Distribution: {'sadness': 0.00011491045006550848, 'anger': 4.5631732064066455e-05, 'love': 0.00010461307829245925, 'surprise': 7.49907485442236e-05, 'fear': 5.250372487353161e-05, 'joy': 0.9996073842048645}
#
# Text: i did not feel any passionate joy
# Predicted Emotion: joy
# Emotion Distribution: {'sadness': 6.981351907597855e-05, 'anger': 0.0001280833239434287, 'love': 0.017991339787840843, 'surprise': 0.00022956884640734643, 'fear': 0.00013968143321108073, 'joy': 0.9814414978027344}
#
# Text: i have nostalgic feelings i have met wonderful people online and the online internet is for me like my second life
# Predicted Emotion: joy
# Emotion Distribution: {'sadness': 7.101718074409291e-05, 'anger': 5.291115303407423e-05, 'love': 0.0008947097230702639, 'surprise': 0.000518330663908273, 'fear': 8.416570199187845e-05, 'joy': 0.9983788728713989}
#
# Text: i feel rejected for trying to find my path to a stronger relationship and bond with god
# Predicted Emotion: sadness
# Emotion Distribution: {'sadness': 0.99967360496521, 'anger': 0.00010027384269051254, 'love': 6.536403088830411e-05, 'surprise': 6.060331725166179e-05, 'fear': 5.046853038948029e-05, 'joy': 4.983077451470308e-05}
#
# Text: i dont know how to deal with this i feel like its becoming apart if who i am im afraid that im going to associate it with regular things so that i will never forget it
# Predicted Emotion: fear
# Emotion Distribution: {'sadness': 0.00032372449641115963, 'anger': 0.00013412575935944915, 'love': 0.00014338649634737521, 'surprise': 0.00021898072736803442, 'fear': 0.9990527033805847, 'joy': 0.0001271403016289696}
#
# Text: i think it s to do with the fact that i know i don t have a lot of time to play catch up and also because my free time for the first time in what feels like forever is really my free time
# Predicted Emotion: joy
# Emotion Distribution: {'sadness': 0.00017422676319256425, 'anger': 8.250320388469845e-05, 'love': 8.273035200545564e-05, 'surprise': 0.00017391168512403965, 'fear': 7.842932973289862e-05, 'joy': 0.9994082450866699}
#
# Text: i feel extremely privileged to live in a country where a vote is legitimate and matters
# Predicted Emotion: joy
# Emotion Distribution: {'sadness': 5.762921500718221e-05, 'anger': 3.606206882977858e-05, 'love': 0.0001275116519536823, 'surprise': 8.268256351584569e-05, 'fear': 4.647467358154245e-05, 'joy': 0.9996495246887207}
#
# Text: i feel a strange gratitude for the hated israeli occupation of sinai that lasted from to for actually recognizing the importance of sinais history
# Predicted Emotion: fear
# Emotion Distribution: {'sadness': 0.0007842734339646995, 'anger': 0.00047071059816516936, 'love': 0.0004904269590042531, 'surprise': 0.13307274878025055, 'fear': 0.8647721409797668, 'joy': 0.0004097424098290503}
#
# Text: im much more peaceful and happy when the house is clean the food is good and my kids arent feeling needy
# Predicted Emotion: sadness
# Emotion Distribution: {'sadness': 0.9996724128723145, 'anger': 0.00010336079867556691, 'love': 6.493710679933429e-05, 'surprise': 5.781975050922483e-05, 'fear': 5.5251071898965165e-05, 'joy': 4.6129101974656805e-05}
#
# Text: i felt that my birthday was my one day to feel special and i could do whatever i wanted
# Predicted Emotion: joy
# Emotion Distribution: {'sadness': 5.844830593559891e-05, 'anger': 3.580930570024066e-05, 'love': 0.00011447738506831229, 'surprise': 0.00010449440742377192, 'fear': 4.7184650611598045e-05, 'joy': 0.999639630317688}
#
# Text: i feel depressed again
# Predicted Emotion: sadness
# Emotion Distribution: {'sadness': 0.9996351003646851, 'anger': 0.0001717338163871318, 'love': 3.823408769676462e-05, 'surprise': 5.0245442253071815e-05, 'fear': 6.301565008470789e-05, 'joy': 4.159871969022788e-05}
#
# Text: i got up saturday morning feeling like crud but determined not to let it get the best of me
# Predicted Emotion: joy
# Emotion Distribution: {'sadness': 9.193420555675402e-05, 'anger': 5.095026426715776e-05, 'love': 0.00011824462126241997, 'surprise': 7.910394197097048e-05, 'fear': 5.056292866356671e-05, 'joy': 0.9996091723442078}
#
# Text: i feel that he is so determined to steal private industries away from citizens of this nation that he has given no time to fighting the real enemies of theu
# Predicted Emotion: joy
# Emotion Distribution: {'sadness': 9.50057219597511e-05, 'anger': 6.774390931241214e-05, 'love': 0.00012728844012599438, 'surprise': 6.628889968851581e-05, 'fear': 4.57301975984592e-05, 'joy': 0.99959796667099}
#
# Text: i would say no not yet and i would feel superior and in fact self righteous even if i would not admit it back then because i remember looking at the point so i can see that the point did come up but i could did not face it to protect my ego
# Predicted Emotion: joy
# Emotion Distribution: {'sadness': 7.03099140082486e-05, 'anger': 4.97298788104672e-05, 'love': 0.00011740304762497544, 'surprise': 7.771397940814495e-05, 'fear': 4.110934241907671e-05, 'joy': 0.9996438026428223}
#
# Text: i feel very tender for anyone who is upset by the bee movie sort of like how you feel about old aunts who dont realize how prickly their whiskers are getting slightly repulsed but very sad for their decline
# Predicted Emotion: love
# Emotion Distribution: {'sadness': 0.00014115017256699502, 'anger': 0.00031034075072966516, 'love': 0.998640239238739, 'surprise': 0.0004049201088491827, 'fear': 0.00021462036238517612, 'joy': 0.00028881209436804056}
#
# Text: i sat up to embrace them and realised that two hours spent shaking my thang in an eighties bar celebrating the fact i am one year closer to death had left my ageing body feeling punished and my normally pink feet blackened
# Predicted Emotion: sadness
# Emotion Distribution: {'sadness': 0.9996583461761475, 'anger': 0.0001262644218513742, 'love': 6.553519051522017e-05, 'surprise': 5.7562985602999106e-05, 'fear': 4.782020550919697e-05, 'joy': 4.445014565135352e-05}
#
# Text: i feel so humiliated by my own self
# Predicted Emotion: sadness
# Emotion Distribution: {'sadness': 0.9996652603149414, 'anger': 9.884352039080113e-05, 'love': 5.118026092532091e-05, 'surprise': 6.711600144626573e-05, 'fear': 5.524988955585286e-05, 'joy': 6.235671753529459e-05}
#
# Text: i feel it is a worthwhile item to me or within my company s mission
# Predicted Emotion: joy
# Emotion Distribution: {'sadness': 7.44204517104663e-05, 'anger': 4.28695093432907e-05, 'love': 0.00011080813419539481, 'surprise': 7.828832895029336e-05, 'fear': 4.7866691602393985e-05, 'joy': 0.9996457099914551}
#
# Text: i feel the earth move tribute to carole king karaoke mix details rel nofollow target blank see more details compare prices img src http www
# Predicted Emotion: sadness
# Emotion Distribution: {'sadness': 0.9996511936187744, 'anger': 8.999145939014852e-05, 'love': 7.014667789917439e-05, 'surprise': 7.204323628684506e-05, 'fear': 4.876298407907598e-05, 'joy': 6.781720730941743e-05}
#
# Text: im the only one with all the feelings and emotions and thats just pathetic of me to do so
# Predicted Emotion: sadness
# Emotion Distribution: {'sadness': 0.9996519088745117, 'anger': 0.00010891759302467108, 'love': 5.423021502792835e-05, 'surprise': 7.54419233999215e-05, 'fear': 4.852438723901287e-05, 'joy': 6.095162098063156e-05}
#
# Text: i can t say for certain why but it actually makes me feel amused and you can be sure it s not just me because other people from our offices told me they have the same a href http news
# Predicted Emotion: joy
# Emotion Distribution: {'sadness': 6.629343261010945e-05, 'anger': 5.749975753133185e-05, 'love': 0.0001118993604904972, 'surprise': 9.134858555626124e-05, 'fear': 4.069562055519782e-05, 'joy': 0.9996321201324463}
#
# Text: i feel defeated but its okay hahaha my mid term holiday was good
# Predicted Emotion: sadness
# Emotion Distribution: {'sadness': 0.9996813535690308, 'anger': 9.079260780708864e-05, 'love': 5.28672244399786e-05, 'surprise': 5.984177550999448e-05, 'fear': 5.51773227925878e-05, 'joy': 5.9968257119180635e-05}
#
# Text: i decided to lay down in my bed but then i started to feel really violent like i wanted to punch and kick things except i didnt wnat to hurt anything
# Predicted Emotion: anger
# Emotion Distribution: {'sadness': 0.00013754381507169455, 'anger': 0.999320387840271, 'love': 0.0001617573871044442, 'surprise': 0.00011332661961205304, 'fear': 0.00020229029178153723, 'joy': 6.47136039333418e-05}
#
# Text: i want to say i feel numb but if i was numb i wouldnt have this pain and i probably wouldnt be able to cry so much
# Predicted Emotion: sadness
# Emotion Distribution: {'sadness': 0.9996210336685181, 'anger': 0.00011586265463847667, 'love': 6.625983951380476e-05, 'surprise': 8.39806380099617e-05, 'fear': 4.4532840547617525e-05, 'joy': 6.827244942542166e-05}
#
# Text: i go again sometime in the future id probably just stick with the african tram which comes with entry fee maybe id spring for the asian tram and if i was feeling particularly brave i might even try the hot air balloon which i thought was reasonable priced at
# Predicted Emotion: joy
# Emotion Distribution: {'sadness': 6.835298700025305e-05, 'anger': 4.041261854581535e-05, 'love': 0.0001129043594119139, 'surprise': 8.011815953068435e-05, 'fear': 5.2205727115506306e-05, 'joy': 0.9996460676193237}
#
# Text: i always feel very shocked by that me threatening
# Predicted Emotion: surprise
# Emotion Distribution: {'sadness': 0.0004043607332278043, 'anger': 0.0005546921165660024, 'love': 0.0005806380650028586, 'surprise': 0.9977148771286011, 'fear': 0.00040637620259076357, 'joy': 0.00033913354855030775}
#
# Text: i was supposed to be alright with not even feeling comfortable in my own home not being able to cook meals without a year old helping me ok with the mounting pile of water and utility bills
# Predicted Emotion: joy
# Emotion Distribution: {'sadness': 0.00011403232929296792, 'anger': 5.6496632169000804e-05, 'love': 8.828635327517986e-05, 'surprise': 9.295871132053435e-05, 'fear': 8.821750088827685e-05, 'joy': 0.9995600581169128}
#
# Text: i am not proud to be british i am not glad to be young and i most certainly do not feel blessed by opportunity
# Predicted Emotion: joy
# Emotion Distribution: {'sadness': 0.00034646279527805746, 'anger': 0.000295128469588235, 'love': 0.28099629282951355, 'surprise': 0.0005147006595507264, 'fear': 0.0001833245187299326, 'joy': 0.7176641225814819}
#
# Text: whenever i put myself in others shoes and try to make the person happy
# Predicted Emotion: joy
# Emotion Distribution: {'sadness': 7.97062530182302e-05, 'anger': 4.6418834244832397e-05, 'love': 0.00012339612294454128, 'surprise': 8.26997056719847e-05, 'fear': 4.64030345028732e-05, 'joy': 0.9996212720870972}
#
# Text: i feel absolutely devastated that gaia is being pushed to her limit in spite of the great strides we seem to be making with all the media attention lately
# Predicted Emotion: sadness
# Emotion Distribution: {'sadness': 0.9996660947799683, 'anger': 9.953678818419576e-05, 'love': 6.49304420221597e-05, 'surprise': 6.34275347692892e-05, 'fear': 5.521022103494033e-05, 'joy': 5.0820293836295605e-05}
#
# Text: i feel around someone the more idiotic i feel hence the unintelligible blabbering
# Predicted Emotion: sadness
# Emotion Distribution: {'sadness': 0.9996410608291626, 'anger': 0.00010518894850974903, 'love': 5.519278420251794e-05, 'surprise': 6.714031042065471e-05, 'fear': 4.645535591407679e-05, 'joy': 8.498125680489466e-05}
#
# Text: i was feeling content and oh so happy with my life
# Predicted Emotion: joy
# Emotion Distribution: {'sadness': 6.726796709699556e-05, 'anger': 3.982076304964721e-05, 'love': 0.0001414306170772761, 'surprise': 7.939479837659746e-05, 'fear': 4.1649775084806606e-05, 'joy': 0.9996304512023926}
#
# Text: i found myself feeling a bit overwhelmed
# Predicted Emotion: fear
# Emotion Distribution: {'sadness': 0.0011938437819480896, 'anger': 0.0005580043070949614, 'love': 0.0005426384159363806, 'surprise': 0.47583895921707153, 'fear': 0.5209818482398987, 'joy': 0.0008847518474794924}
#
# Text: i don t know how i feel i guess it s one of those moments where you want to feel like you re accepted even though whatever you did or did not get mattered to you the most
# Predicted Emotion: joy
# Emotion Distribution: {'sadness': 0.0003557642630767077, 'anger': 0.00036150068626739085, 'love': 0.4121098220348358, 'surprise': 0.0006389159825630486, 'fear': 0.00027137863798998296, 'joy': 0.5862626433372498}
#
# Text: i wasn t sure what this gnawing feeling i was having but i was getting agitated sitting around doing nothing
# Predicted Emotion: anger
# Emotion Distribution: {'sadness': 0.000583734130486846, 'anger': 0.9658008217811584, 'love': 0.00022969560814090073, 'surprise': 0.0003287389990873635, 'fear': 0.03276999667286873, 'joy': 0.0002870209573302418}
#
# Text: i dont remember how january was like last year thats why i need a real diary but this one is feeling bitter dark and boring
# Predicted Emotion: anger
# Emotion Distribution: {'sadness': 0.00017874855257105082, 'anger': 0.9993997812271118, 'love': 0.00014781668141949922, 'surprise': 9.16987846721895e-05, 'fear': 0.00012050601071678102, 'joy': 6.130188558017835e-05}
#
# Text: i normally find intimidating but shes crazy about tiny little foreign food places and people like her so i feel less socially intimidated when im with her
# Predicted Emotion: fear
# Emotion Distribution: {'sadness': 0.00025730926427058876, 'anger': 0.00013395858695730567, 'love': 0.00013138086069375277, 'surprise': 0.00023573751968797296, 'fear': 0.9990994930267334, 'joy': 0.0001421475171810016}
#
# Text: i feel quite researched and intelligent about my confidence in consuming meat
# Predicted Emotion: joy
# Emotion Distribution: {'sadness': 6.85543636791408e-05, 'anger': 5.332953514880501e-05, 'love': 9.325322025688365e-05, 'surprise': 0.00012209767010062933, 'fear': 6.93128677085042e-05, 'joy': 0.9995933175086975}
#
# Text: i ate something wrong so i feel terrible all day
# Predicted Emotion: sadness
# Emotion Distribution: {'sadness': 0.9996474981307983, 'anger': 0.00012530940875876695, 'love': 4.6394867240451276e-05, 'surprise': 6.374855001922697e-05, 'fear': 7.368133083218709e-05, 'joy': 4.3446871131891385e-05}
#
# Text: i feel like the place is even more messy
# Predicted Emotion: sadness
# Emotion Distribution: {'sadness': 0.999627947807312, 'anger': 0.0001228631444973871, 'love': 8.188306674128398e-05, 'surprise': 7.224315049825236e-05, 'fear': 4.8080000851769e-05, 'joy': 4.709041604655795e-05}
#
# Text: i feel unprotected even while travelling alone
# Predicted Emotion: fear
# Emotion Distribution: {'sadness': 0.0008403386455029249, 'anger': 9.018642595037818e-05, 'love': 0.0001630943879717961, 'surprise': 0.00026314909337088466, 'fear': 0.9985042810440063, 'joy': 0.00013899420446250588}
#
# Text: i believe feeling duality suffering soul growth tells of an ending or a decline or a change of direction often one associated with emotions and it offers one possible response to that decline or change moving on
# Predicted Emotion: sadness
# Emotion Distribution: {'sadness': 0.9996744394302368, 'anger': 0.00010416869190521538, 'love': 5.9609599702525884e-05, 'surprise': 5.910534309805371e-05, 'fear': 6.513980770250782e-05, 'joy': 3.7515397707466036e-05}
#
# Text: i feel really uptight and unable to unwind
# Predicted Emotion: fear
# Emotion Distribution: {'sadness': 0.00023569451877847314, 'anger': 0.0001060185459209606, 'love': 0.0001345404307357967, 'surprise': 0.0002717705792747438, 'fear': 0.9991105198860168, 'joy': 0.00014133439981378615}
#
# Text: im learning mandarin chinese now in preparation for a trip to tianjin this september and already only four lessons in i feel like i have a handle on the basics and im thrilled to have some insight into a language that had always been a total mystery to me
# Predicted Emotion: joy
# Emotion Distribution: {'sadness': 9.542409679852426e-05, 'anger': 7.485967216780409e-05, 'love': 7.386957440758124e-05, 'surprise': 0.00023398009943775833, 'fear': 0.00012752616021316499, 'joy': 0.999394416809082}
#
# Text: i think and it feels a little weird
# Predicted Emotion: fear
# Emotion Distribution: {'sadness': 0.000886239402461797, 'anger': 0.0005834609619341791, 'love': 0.0006768439197912812, 'surprise': 0.17285551130771637, 'fear': 0.8242730498313904, 'joy': 0.0007249104091897607}
#
# Text: i feel my truth is accepted and not judged because well
# Predicted Emotion: joy
# Emotion Distribution: {'sadness': 0.0002496255037840456, 'anger': 0.0002267285017296672, 'love': 0.13812094926834106, 'surprise': 0.00040346270543523133, 'fear': 0.00019928051915485412, 'joy': 0.86080002784729}
#
# Text: i feel like an indecisive idiot
# Predicted Emotion: fear
# Emotion Distribution: {'sadness': 0.00023937856894917786, 'anger': 8.85415356606245e-05, 'love': 0.00012915550905745476, 'surprise': 0.000313014053972438, 'fear': 0.9990621209144592, 'joy': 0.00016780581790953875}
#
# Text: i just couldn t decide what to feel she didn t tell me and then she blamed me because i never told her it would be like that
# Predicted Emotion: sadness
# Emotion Distribution: {'sadness': 0.9995695948600769, 'anger': 0.00024097149434965104, 'love': 5.076951492810622e-05, 'surprise': 5.441026951302774e-05, 'fear': 4.2903953726636246e-05, 'joy': 4.140937380725518e-05}
#
# Text: i feel for vets the animals whose lives they save are always going to be hostile
# Predicted Emotion: anger
# Emotion Distribution: {'sadness': 0.00010384027700638399, 'anger': 0.9992730021476746, 'love': 0.00020937698718626052, 'surprise': 0.00011862709652632475, 'fear': 0.00024227984249591827, 'joy': 5.29391472809948e-05}
#
# Text: i still feel more than anything else humiliated whenever i think of everything that s happened
# Predicted Emotion: sadness
# Emotion Distribution: {'sadness': 0.9996525049209595, 'anger': 0.00010288531484548002, 'love': 5.223275366006419e-05, 'surprise': 7.05766215105541e-05, 'fear': 4.831030673813075e-05, 'joy': 7.359188020927832e-05}
#
# Text: i feel like i finally want to write about one of my vain hobbies makeup
# Predicted Emotion: sadness
# Emotion Distribution: {'sadness': 0.9996702671051025, 'anger': 0.00011168250784976408, 'love': 5.522029459825717e-05, 'surprise': 5.89329210924916e-05, 'fear': 5.6971599406097084e-05, 'joy': 4.7039709897944704e-05}
#
# Text: i regularly feel embarrassed about
# Predicted Emotion: sadness
# Emotion Distribution: {'sadness': 0.9996503591537476, 'anger': 0.00012577489542309195, 'love': 4.7421770432265475e-05, 'surprise': 6.17377954768017e-05, 'fear': 6.770528852939606e-05, 'joy': 4.697856638813391e-05}
#
# Text: i then realized that if i want to shoot weddings of clients who i connect with and feel comfortable with i must allow them to get to know me
# Predicted Emotion: joy
# Emotion Distribution: {'sadness': 7.129594450816512e-05, 'anger': 3.9966063923202455e-05, 'love': 0.00011865960550494492, 'surprise': 7.904403901193291e-05, 'fear': 5.7535165979061276e-05, 'joy': 0.9996335506439209}
#
# Text: i checked the babys heartbeat and continued to feel him moving so besides feeling terrible i was at peace
# Predicted Emotion: sadness
# Emotion Distribution: {'sadness': 0.999652624130249, 'anger': 0.00010945247049676254, 'love': 5.460598913487047e-05, 'surprise': 6.41927617834881e-05, 'fear': 7.320808799704537e-05, 'joy': 4.59488328488078e-05}
#
# Text: i found myself giggling and clapping my hands more often than a five year old at the ice cream wagon and there was never a point where i didnt feel genuinely entertained
# Predicted Emotion: joy
# Emotion Distribution: {'sadness': 8.434707706328481e-05, 'anger': 8.460068784188479e-05, 'love': 8.801325020613149e-05, 'surprise': 0.00022309579071588814, 'fear': 7.665101293241605e-05, 'joy': 0.9994432330131531}
#
# Text: i feel more virtuous just looking at the pictures in her books
# Predicted Emotion: joy
# Emotion Distribution: {'sadness': 6.0730468248948455e-05, 'anger': 4.1837360186036676e-05, 'love': 0.0001038362315739505, 'surprise': 0.0001012211650959216, 'fear': 6.47820343147032e-05, 'joy': 0.9996275901794434}
#
# Text: i guess it doesn t help that i got sick on black friday and was forced against my will to maintain my promise to stay in but being back in the city feels amazing
# Predicted Emotion: surprise
# Emotion Distribution: {'sadness': 0.002205879194661975, 'anger': 0.0014928459422662854, 'love': 0.0017199814319610596, 'surprise': 0.8611505031585693, 'fear': 0.0021746025886386633, 'joy': 0.13125620782375336}
#
# Text: i did feel rather like a celebrity and widget stood and let herself be admired while she drank orange squash from my cup
# Predicted Emotion: love
# Emotion Distribution: {'sadness': 0.0008250853279605508, 'anger': 0.00046538905007764697, 'love': 0.9918381571769714, 'surprise': 0.0009865538449957967, 'fear': 0.00015112895925994962, 'joy': 0.005733777303248644}
#
# Text: i really feel like having my own space anymore is a really vain idea
# Predicted Emotion: sadness
# Emotion Distribution: {'sadness': 0.9996691942214966, 'anger': 0.00010796637070598081, 'love': 5.9233290812699124e-05, 'surprise': 6.32377850706689e-05, 'fear': 5.03607552673202e-05, 'joy': 4.9966416554525495e-05}
#
# Text: i can reasonably deduce that my grandfather did also love my mother but that doesn t negate the lifetime of damage that the feeling of being unloved and unwanted created in her
# Predicted Emotion: sadness
# Emotion Distribution: {'sadness': 0.9996340274810791, 'anger': 0.00012504066398832947, 'love': 9.404816228197888e-05, 'surprise': 5.9415244322735816e-05, 'fear': 5.245717693469487e-05, 'joy': 3.505940912873484e-05}
#
# Text: im saying this having not read the book the characters were hard to empathise for and a lot of the time i found myself not feeling distraught when something happened but rather uninterested and blank
# Predicted Emotion: fear
# Emotion Distribution: {'sadness': 0.00043978093890473247, 'anger': 0.00014675910642836243, 'love': 0.00011121285206172615, 'surprise': 0.00021939924045000225, 'fear': 0.998984158039093, 'joy': 9.870028588920832e-05}
#
# Text: im spending less especially on stuff that wont last long not bringing tons of stuff into the house and i feel more positive about my holiday gift giving
# Predicted Emotion: joy
# Emotion Distribution: {'sadness': 6.463140744017437e-05, 'anger': 4.0667619032319635e-05, 'love': 0.00014055111387278885, 'surprise': 6.874318205518648e-05, 'fear': 4.3512016418389976e-05, 'joy': 0.9996418952941895}
#
# Text: i feel embarrassed for not having lost weight again and im afraid that another week of disappointing news at the scale will cause people to give up on me and stop following the blog
# Predicted Emotion: sadness
# Emotion Distribution: {'sadness': 0.9996663331985474, 'anger': 0.00011139763228129596, 'love': 5.4679483582731336e-05, 'surprise': 6.48553905193694e-05, 'fear': 6.290221062954515e-05, 'joy': 3.982264388469048e-05}
#
# Text: i feel a little guilty that i am not doing the same and as i contemplate going back to get some money the prisoners begin to enter the room
# Predicted Emotion: sadness
# Emotion Distribution: {'sadness': 0.9996727705001831, 'anger': 0.00010262976138619706, 'love': 5.736149614676833e-05, 'surprise': 6.507140642497689e-05, 'fear': 4.88439982291311e-05, 'joy': 5.3321007726481184e-05}
#
# Text: i careened from feeling confident in my abilities as a writer to being equally sure that i will never ever write anything worth reading
# Predicted Emotion: joy
# Emotion Distribution: {'sadness': 5.8274697948945686e-05, 'anger': 4.106817505089566e-05, 'love': 0.00011961971176788211, 'surprise': 7.885145168984309e-05, 'fear': 5.220936145633459e-05, 'joy': 0.9996498823165894}
#
# Text: i feel very honoured to have been asked
# Predicted Emotion: joy
# Emotion Distribution: {'sadness': 5.340879943105392e-05, 'anger': 3.959070090786554e-05, 'love': 0.0001226193126058206, 'surprise': 9.597213647793978e-05, 'fear': 4.810242899111472e-05, 'joy': 0.9996403455734253}
#
# Text: i feel pathetic that i can hardly go a whole day not talking to him
# Predicted Emotion: sadness
# Emotion Distribution: {'sadness': 0.9996747970581055, 'anger': 0.00010730232315836474, 'love': 4.8177265853155404e-05, 'surprise': 6.40928847133182e-05, 'fear': 5.162547677173279e-05, 'joy': 5.4123520385473967e-05}
#
# Text: i have faith in supreme power and i accept everything and all incidence occuring in life sometimes like today it really makes me feel very very dull and i start crying
# Predicted Emotion: sadness
# Emotion Distribution: {'sadness': 0.9996410608291626, 'anger': 0.00011989583435934037, 'love': 6.129312532721087e-05, 'surprise': 6.403457518899813e-05, 'fear': 3.8834525184938684e-05, 'joy': 7.488064875360578e-05}
#
# Text: i want you to feel just as humiliated as you made me feel in school
# Predicted Emotion: sadness
# Emotion Distribution: {'sadness': 0.9996683597564697, 'anger': 9.9532087915577e-05, 'love': 4.844297291128896e-05, 'surprise': 6.592913996428251e-05, 'fear': 5.307608444127254e-05, 'joy': 6.470274820458144e-05}
#
# Text: i is desperate for kareena akshay kumar will play a double role in flash forward minissha says i still feel today amisha patel in a glamorous avtaar
# Predicted Emotion: joy
# Emotion Distribution: {'sadness': 7.479972555302083e-05, 'anger': 4.271615398465656e-05, 'love': 0.00010535461478866637, 'surprise': 8.41622386360541e-05, 'fear': 5.472417251439765e-05, 'joy': 0.9996383190155029}
#
# Text: i feel like i just doomed myself
# Predicted Emotion: sadness
# Emotion Distribution: {'sadness': 0.9996652603149414, 'anger': 9.497805876890197e-05, 'love': 5.620033698505722e-05, 'surprise': 6.456545816035941e-05, 'fear': 5.9433703427203e-05, 'joy': 5.9532354498514906e-05}
#
# Text: always when i am well succeded
# Predicted Emotion: joy
# Emotion Distribution: {'sadness': 0.0001147924704127945, 'anger': 8.564064046368003e-05, 'love': 0.0001510489237261936, 'surprise': 7.748114876449108e-05, 'fear': 6.95837297826074e-05, 'joy': 0.9995014667510986}
#
# Text: i felt so bad for the bad grade and feeling like having to hide it that i didnt know what to say except to declare in all my frustration that i hated school
# Predicted Emotion: anger
# Emotion Distribution: {'sadness': 0.08142989128828049, 'anger': 0.9175720810890198, 'love': 0.00037101219641044736, 'surprise': 0.00023468636209145188, 'fear': 0.00018517936405260116, 'joy': 0.00020717161532957107}
#
# Text: i feel assaulted by this shit storm of confusion anger and hurt feelings that tsunami d us both away from each other
# Predicted Emotion: fear
# Emotion Distribution: {'sadness': 0.0815512016415596, 'anger': 0.0004898521583527327, 'love': 0.0003211172006558627, 'surprise': 0.0015638477634638548, 'fear': 0.9158554673194885, 'joy': 0.0002185137418564409}
#
# Text: i feel so fucking low
# Predicted Emotion: sadness
# Emotion Distribution: {'sadness': 0.9996198415756226, 'anger': 0.0001697121624602005, 'love': 5.476910519064404e-05, 'surprise': 5.087535464554094e-05, 'fear': 6.671730807283893e-05, 'joy': 3.799875048571266e-05}
#
# Text: i feel betrayed and angry and sad at the same time dammit
# Predicted Emotion: sadness
# Emotion Distribution: {'sadness': 0.9962080717086792, 'anger': 0.0006725998246110976, 'love': 0.0023323800414800644, 'surprise': 7.606569852214307e-05, 'fear': 0.0002712207206059247, 'joy': 0.0004395957803353667}
#
# Text: i feel reassured that the county government in my county takes the murder of an illegal immigrant in a back alley seriously enough to prosecute someone years later
# Predicted Emotion: joy
# Emotion Distribution: {'sadness': 8.425132546108216e-05, 'anger': 4.4254364183871076e-05, 'love': 9.799185500014573e-05, 'surprise': 7.688323239563033e-05, 'fear': 6.960708560654894e-05, 'joy': 0.9996271133422852}
#
# Text: i don t know how i feel about my submissive learning how to use a firearm
# Predicted Emotion: sadness
# Emotion Distribution: {'sadness': 0.9996294975280762, 'anger': 9.983708150684834e-05, 'love': 8.977453398983926e-05, 'surprise': 6.261119415285066e-05, 'fear': 8.245326898759231e-05, 'joy': 3.587998071452603e-05}
#
# Text: i feel so drained at the end of a novel because i try my very hardest to get something from it that will change and impact my life
# Predicted Emotion: sadness
# Emotion Distribution: {'sadness': 0.9996720552444458, 'anger': 0.00010483867663424462, 'love': 5.08074153913185e-05, 'surprise': 6.457704148488119e-05, 'fear': 4.9976137233898044e-05, 'joy': 5.788504859083332e-05}
#
# Text: i was truly surprised and feel quite honored
# Predicted Emotion: joy
# Emotion Distribution: {'sadness': 5.008692460251041e-05, 'anger': 4.175777576165274e-05, 'love': 0.00011121525312773883, 'surprise': 0.00021580250177066773, 'fear': 4.840819019591436e-05, 'joy': 0.9995328187942505}
#
# Text: i hate feeling alone too
# Predicted Emotion: sadness
# Emotion Distribution: {'sadness': 0.9996464252471924, 'anger': 0.00013322460290510207, 'love': 6.453377136494964e-05, 'surprise': 5.443645568448119e-05, 'fear': 6.195838068379089e-05, 'joy': 3.936410939786583e-05}
#
# Text: i feel like if people accepted that wed get along a lot better
# Predicted Emotion: joy
# Emotion Distribution: {'sadness': 0.0002908847527578473, 'anger': 0.0003672645543701947, 'love': 0.425004243850708, 'surprise': 0.0006536536384373903, 'fear': 0.0002944250591099262, 'joy': 0.57338947057724}
#
# Text: i feel the creative juices beginning to flow again
# Predicted Emotion: joy
# Emotion Distribution: {'sadness': 7.255242235260084e-05, 'anger': 5.180896550882608e-05, 'love': 0.00011432345490902662, 'surprise': 8.05460658739321e-05, 'fear': 5.1480845286278054e-05, 'joy': 0.9996292591094971}
#
# Text: i feel suffocated and paranoid
# Predicted Emotion: fear
# Emotion Distribution: {'sadness': 0.00026418297784402966, 'anger': 0.0001105543487938121, 'love': 0.0001326805358985439, 'surprise': 0.00030390953179448843, 'fear': 0.999026894569397, 'joy': 0.00016182297258637846}
#
# Text: i would call success and i was feeling pretty depressed about the state of clothes
# Predicted Emotion: sadness
# Emotion Distribution: {'sadness': 0.9996777772903442, 'anger': 0.00011183948663529009, 'love': 4.5696004235651344e-05, 'surprise': 5.642208270728588e-05, 'fear': 6.545981159433722e-05, 'joy': 4.296248152968474e-05}
#
# Text: i feel soo lonely
# Predicted Emotion: sadness
# Emotion Distribution: {'sadness': 0.9996370077133179, 'anger': 0.00015032352530397475, 'love': 6.849403871456161e-05, 'surprise': 5.671703547704965e-05, 'fear': 4.996495044906624e-05, 'joy': 3.7510344554902986e-05}
#
# Text: i see on wednesday im feeling fantastic these days and i can tell im getting smaller and smaller
# Predicted Emotion: joy
# Emotion Distribution: {'sadness': 5.6381224567303434e-05, 'anger': 4.005775190307759e-05, 'love': 0.00011257692676736042, 'surprise': 9.980025060940534e-05, 'fear': 4.553619146463461e-05, 'joy': 0.9996457099914551}
#
# Text: i feel as though i am on another adventure and i am more curious about it than anything else
# Predicted Emotion: surprise
# Emotion Distribution: {'sadness': 0.00040885404450818896, 'anger': 0.0006301195826381445, 'love': 0.0008420299855060875, 'surprise': 0.9973564147949219, 'fear': 0.0004482249787542969, 'joy': 0.0003143699432257563}
#
# Text: i also feel the sidebar is messy
# Predicted Emotion: sadness
# Emotion Distribution: {'sadness': 0.9996311664581299, 'anger': 0.0001263829180970788, 'love': 8.15577877801843e-05, 'surprise': 6.773227505618706e-05, 'fear': 4.5022668928140774e-05, 'joy': 4.8092355427797884e-05}
#
# Text: i feel respected and secure where i can journey toward loving and be loved in return
# Predicted Emotion: joy
# Emotion Distribution: {'sadness': 7.748906500637531e-05, 'anger': 3.676686901599169e-05, 'love': 0.0002841395908035338, 'surprise': 6.558849418070167e-05, 'fear': 3.3481883292552084e-05, 'joy': 0.9995025396347046}
#
# Text: im feeling relieved yet painful but something inside me is creepily numb i feel like a ghost in the hallways the way i used to just dont tell me its only another time to succumb
# Predicted Emotion: joy
# Emotion Distribution: {'sadness': 0.000717650749720633, 'anger': 7.276321412064135e-05, 'love': 0.0001174740245915018, 'surprise': 0.0001224967563757673, 'fear': 7.600208482472226e-05, 'joy': 0.9988935589790344}
#
# Text: i feel more amazed and more thankful for having e in our lives
# Predicted Emotion: surprise
# Emotion Distribution: {'sadness': 0.00042273642611689866, 'anger': 0.0007828568341210485, 'love': 0.000532064470462501, 'surprise': 0.9975230097770691, 'fear': 0.00045066626626066864, 'joy': 0.00028868025401607156}
#
# Text: i must confess that im still feeling very uncertain about how god is going to work everything out
# Predicted Emotion: fear
# Emotion Distribution: {'sadness': 0.0002420338714728132, 'anger': 0.00010323587048333138, 'love': 0.00015258422354236245, 'surprise': 0.00021843051945324987, 'fear': 0.9991023540496826, 'joy': 0.00018142996123060584}
#
# Text: i have this really bad feeling that cold is what i will be for a few months
# Predicted Emotion: anger
# Emotion Distribution: {'sadness': 0.00020207968191243708, 'anger': 0.9993410706520081, 'love': 0.000177562193130143, 'surprise': 0.00011748832912417129, 'fear': 0.00010294972162228078, 'joy': 5.8870264183497056e-05}
#
# Text: ive been feeling sort of depressed
# Predicted Emotion: sadness
# Emotion Distribution: {'sadness': 0.9996471405029297, 'anger': 0.0001582480763318017, 'love': 4.5030559704173356e-05, 'surprise': 5.477901140693575e-05, 'fear': 5.0584912969497964e-05, 'joy': 4.422647543833591e-05}
#
# Text: i am just feeling as indecisive as ever i suppose
# Predicted Emotion: fear
# Emotion Distribution: {'sadness': 0.0002327583497390151, 'anger': 9.478633000981063e-05, 'love': 0.000126775965327397, 'surprise': 0.0003277786017861217, 'fear': 0.9990745782852173, 'joy': 0.00014340851339511573}
#
# Text: i felt abandoned for what seemed like the millionth time in my life and i spent the last several days feeling sorry for myself when i should have been picking myself up in order to help my friends
# Predicted Emotion: sadness
# Emotion Distribution: {'sadness': 0.999671220779419, 'anger': 0.0001025783276418224, 'love': 5.9760182921309024e-05, 'surprise': 6.529845268232748e-05, 'fear': 5.587787745753303e-05, 'joy': 4.5364839024841785e-05}
#
# Text: i enjoy the day more when i feel cute
# Predicted Emotion: joy
# Emotion Distribution: {'sadness': 5.8192978031001985e-05, 'anger': 4.245001764502376e-05, 'love': 0.0001229104382218793, 'surprise': 8.92333555384539e-05, 'fear': 4.8314490413758904e-05, 'joy': 0.9996389150619507}
#
# Text: i was bonded to that point in time and still feel fond of this memory
# Predicted Emotion: love
# Emotion Distribution: {'sadness': 0.00018142488261219114, 'anger': 0.0003447668859735131, 'love': 0.9984971284866333, 'surprise': 0.000411628105212003, 'fear': 0.0003249988949391991, 'joy': 0.00024003464204724878}
#
# Text: i will remember to come to you when i feel beaten and depressed because in faith only can we truly be healed
# Predicted Emotion: sadness
# Emotion Distribution: {'sadness': 0.999675989151001, 'anger': 0.00010265642049489543, 'love': 5.947686804574914e-05, 'surprise': 6.121576006989926e-05, 'fear': 4.9580699851503596e-05, 'joy': 5.107544347993098e-05}
#
# Text: i sometimes feel is carried in my heart just by loving my child so fiercely
# Predicted Emotion: love
# ...
#
# Text: i feel that bassanio is sincere about wooing portia
# Predicted Emotion: joy
# Emotion Distribution: {'sadness': 6.701282109133899e-05, 'anger': 4.0300768887391314e-05, 'love': 0.00013744265015702695, 'surprise': 7.434179860865697e-05, 'fear': 4.465008169063367e-05, 'joy': 0.9996362924575806}
#
# Text: i just feel so hopeless sometimes
# Predicted Emotion: sadness
# Emotion Distribution: {'sadness': 0.9996597766876221, 'anger': 9.08171568880789e-05, 'love': 6.148102693259716e-05, 'surprise': 6.789829058106989e-05, 'fear': 7.258322148118168e-05, 'joy': 4.745624028146267e-05}
#
# Text: i was cooking my dinner feeling pretty melancholy when zane lowe gave it the first spin on his radio one show on tuesday and the song matched my mood perfectly
# Predicted Emotion: sadness
# Emotion Distribution: {'sadness': 0.9996547698974609, 'anger': 0.00013067893451079726, 'love': 6.458700954681262e-05, 'surprise': 5.095487358630635e-05, 'fear': 6.320503598544747e-05, 'joy': 3.583331636036746e-05}
#
# Text: i was gaining weight getting a lot stronger and feeling amazing
# Predicted Emotion: joy
# Emotion Distribution: {'sadness': 0.002755408175289631, 'anger': 0.0017470463644713163, 'love': 0.002182614989578724, 'surprise': 0.4397366940975189, 'fear': 0.003110910300165415, 'joy': 0.550467312335968}
#
# Text: i am feeling amazing and seeing the difference
# Predicted Emotion: surprise
# Emotion Distribution: {'sadness': 0.002581097884103656, 'anger': 0.0016177588840946555, 'love': 0.002322631422430277, 'surprise': 0.8268399238586426, 'fear': 0.0032945882994681597, 'joy': 0.16334399580955505}
#
# Text: im feeling playful a href http
# Predicted Emotion: joy
# Emotion Distribution: {'sadness': 6.375106022460386e-05, 'anger': 5.704430441255681e-05, 'love': 0.00010698143159970641, 'surprise': 9.942936594597995e-05, 'fear': 5.65967129659839e-05, 'joy': 0.9996161460876465}
#
# Text: i check you when you re sleeping feel your nose and toes to be sure you aren t too hot or cold
# Predicted Emotion: love
# Emotion Distribution: {'sadness': 0.0001195477379951626, 'anger': 0.0006122297490946949, 'love': 0.9979390501976013, 'surprise': 0.0005614137626253068, 'fear': 0.00029723139596171677, 'joy': 0.0004705001483671367}
#
# Text: i can send my children to a private school and i don t have to apologize explain or feel embarrassed about this choice
# Predicted Emotion: sadness
# Emotion Distribution: {'sadness': 0.9996668100357056, 'anger': 0.00010824736091308296, 'love': 5.364226672099903e-05, 'surprise': 6.632026634179056e-05, 'fear': 5.8944067859556526e-05, 'joy': 4.598109080689028e-05}
#
# Text: i remember wanting to fit in so bad and feeling like no one liked me
# Predicted Emotion: love
# Emotion Distribution: {'sadness': 0.00019351676746737212, 'anger': 0.0004044610250275582, 'love': 0.9984930753707886, 'surprise': 0.00040708197047933936, 'fear': 0.0001412423443980515, 'joy': 0.00036069765337742865}
#
# Text: i also feel it helped the newbie bloggers connect and feel welcomed immediately
# Predicted Emotion: joy
# Emotion Distribution: {'sadness': 6.231090083019808e-05, 'anger': 3.761307380045764e-05, 'love': 0.00014837636263109744, 'surprise': 7.122829265426844e-05, 'fear': 4.158847877988592e-05, 'joy': 0.9996387958526611}
#
# Text: i feel divine in more ways than one
# Predicted Emotion: joy
# Emotion Distribution: {'sadness': 6.292785838013515e-05, 'anger': 4.387680019135587e-05, 'love': 0.00010053733421955258, 'surprise': 0.00011326777894282714, 'fear': 5.1768227422144264e-05, 'joy': 0.9996275901794434}
#
# Text: i was feeling disheartened when going on dates because i didn t feel i was meeting anyone i clicked with or would consider a long term relationship with
# Predicted Emotion: sadness
# Emotion Distribution: {'sadness': 0.999666690826416, 'anger': 0.00010101297084474936, 'love': 7.053920126054436e-05, 'surprise': 5.8494333643466234e-05, 'fear': 6.615683378186077e-05, 'joy': 3.7137564504519105e-05}
#
# Text: i am now and i still feel the aching loneliness of that quiet hospital room
# Predicted Emotion: sadness
# Emotion Distribution: {'sadness': 0.99954754114151, 'anger': 0.00014498156087938696, 'love': 0.00015069660730659962, 'surprise': 6.562735507031903e-05, 'fear': 5.555658572120592e-05, 'joy': 3.5560042306315154e-05}
#
# Text: i was feeling especially brave and asked me to take her engagement photos in hawaii
# Predicted Emotion: joy
# Emotion Distribution: {'sadness': 5.6195138313341886e-05, 'anger': 4.1133753256872296e-05, 'love': 0.00012400840932969004, 'surprise': 8.414973854087293e-05, 'fear': 5.404940384323709e-05, 'joy': 0.9996404647827148}
#
# Text: i see how it turns out i ll talk more about it right now i m feeling proud and scared and a little sick i think that s adrenaline though
# Predicted Emotion: joy
# Emotion Distribution: {'sadness': 0.00011558584810700268, 'anger': 6.317836232483387e-05, 'love': 8.145644824253395e-05, 'surprise': 0.00011199278378626332, 'fear': 7.936844485811889e-05, 'joy': 0.9995483756065369}
#
# Text: im feeling so damn gloomy too
# Predicted Emotion: sadness
# Emotion Distribution: {'sadness': 0.9996587038040161, 'anger': 0.00012206617975607514, 'love': 7.157958316383883e-05, 'surprise': 5.7105084124486893e-05, 'fear': 4.4831318518845364e-05, 'joy': 4.575941420625895e-05}
#
# Text: i can feel the warmth of the gentle sun
# Predicted Emotion: love
# Emotion Distribution: {'sadness': 0.000289196235826239, 'anger': 0.0003204836684744805, 'love': 0.9984570741653442, 'surprise': 0.0003408945631235838, 'fear': 0.00034367109765298665, 'joy': 0.00024872043286450207}
#
# Text: i guess as long as the table in the above is policy discussions and not working and fighting for change within the american theater which i feel im very devoted to i can get behind it though it seems slanted
# Predicted Emotion: love
# Emotion Distribution: {'sadness': 0.00016936182510107756, 'anger': 0.00033303603413514793, 'love': 0.9986262321472168, 'surprise': 0.00037173129385337234, 'fear': 0.00020402845984790474, 'joy': 0.000295543868560344}
#
# Text: i was feeling more optimistic with blue skies no wind and temperatures hovering at about degrees
# Predicted Emotion: joy
# Emotion Distribution: {'sadness': 6.454111280618235e-05, 'anger': 4.100734440726228e-05, 'love': 0.0001332468818873167, 'surprise': 7.00412128935568e-05, 'fear': 4.7271736548282206e-05, 'joy': 0.9996439218521118}
#
# Text: i also feel the need to mention that the animators at pixar sure outdid themselves this time
# Predicted Emotion: joy
# Emotion Distribution: {'sadness': 0.000109870481537655, 'anger': 7.037513569230214e-05, 'love': 8.339508349308744e-05, 'surprise': 0.00011643679317785427, 'fear': 7.20498719601892e-05, 'joy': 0.9995477795600891}
#
# Text: i was feeling playful that day and replied with a lighthearted bit of banter unwittingly replacing her question mark with a solid check mark my voice was just right for the funny yet informational for dummies series
# Predicted Emotion: joy
# Emotion Distribution: {'sadness': 7.608647138113156e-05, 'anger': 7.31011969037354e-05, 'love': 0.00011158322013216093, 'surprise': 9.4953655207064e-05, 'fear': 5.655873610521667e-05, 'joy': 0.9995877146720886}
#
# Text: i was feeling rather cranky cos i was thinking about the lack of sleep i had bah
# Predicted Emotion: anger
# Emotion Distribution: {'sadness': 0.00016322916781064123, 'anger': 0.9993513226509094, 'love': 0.00019714560767170042, 'surprise': 0.0001297684502787888, 'fear': 0.00010275862587150186, 'joy': 5.5777913075871766e-05}
#
# Text: i feel scared anxious
# Predicted Emotion: fear
# Emotion Distribution: {'sadness': 0.00021247794211376458, 'anger': 9.967885125661269e-05, 'love': 0.00016378486179746687, 'surprise': 0.00022262083075474948, 'fear': 0.9991061091423035, 'joy': 0.00019529522978700697}
#
# Text: i feel it is really valuable to contemplate on that phrase thy will be done in all of our lives
# Predicted Emotion: joy
# Emotion Distribution: {'sadness': 6.299393862718716e-05, 'anger': 3.7931862607365474e-05, 'love': 0.0001292354572797194, 'surprise': 8.302070637000725e-05, 'fear': 4.250294659868814e-05, 'joy': 0.9996442794799805}
#
# Text: i spent last night on the couch feeling like i was suffering from hypothermia while the house remained at a balmy
# Predicted Emotion: sadness
# Emotion Distribution: {'sadness': 0.9985207915306091, 'anger': 0.00036907268804498017, 'love': 6.817506073275581e-05, 'surprise': 6.757798109902069e-05, 'fear': 0.000890125404112041, 'joy': 8.426392741966993e-05}
#
# Text: i dont want to always be judgmental of particular men or scenarios that i often see in this area but with so much trafficking forced sex work and what basically amounts to slavery its hard not to feel slightly embittered and disillusioned
# Predicted Emotion: anger
# Emotion Distribution: {'sadness': 0.03234555199742317, 'anger': 0.9622231125831604, 'love': 0.000778603192884475, 'surprise': 0.004202030133455992, 'fear': 0.0002018109371419996, 'joy': 0.0002488881000317633}
#
# Text: i have no strong feelings for this book neither hated nor loved it
# Predicted Emotion: anger
# Emotion Distribution: {'sadness': 0.09469440579414368, 'anger': 0.9004831910133362, 'love': 0.003860263153910637, 'surprise': 0.0004574613703880459, 'fear': 0.0001971256424440071, 'joy': 0.0003075907879974693}
#
# Text: i blunder through my life ignoring the pain when at all possible and feeling only that dull ache like hearing only the slightest echo of a scream far away
# Predicted Emotion: sadness
# Emotion Distribution: {'sadness': 0.9996366500854492, 'anger': 0.00011242635082453489, 'love': 7.393280975520611e-05, 'surprise': 6.902094901306555e-05, 'fear': 4.2487503378652036e-05, 'joy': 6.541692710015923e-05}
#
# Text: im feeling cooped up and impatient and annoyingly bored
# Predicted Emotion: anger
# Emotion Distribution: {'sadness': 0.0002043130516540259, 'anger': 0.9993613362312317, 'love': 0.00013244700676295906, 'surprise': 8.754605369176716e-05, 'fear': 0.00012568649253807962, 'joy': 8.863717812346295e-05}
#
# Text: im able to refine my poses and concepts without feeling rushed
# Predicted Emotion: anger
# Emotion Distribution: {'sadness': 0.00010457296593813226, 'anger': 0.9991430044174194, 'love': 0.0001366285141557455, 'surprise': 0.00010456428572069854, 'fear': 0.00041978564695455134, 'joy': 9.139518806478009e-05}
#
# Text: im thinking well i could be a bit smaller but for health reasons and i should see a doctor more regularly because im feeling crappy
# Predicted Emotion: sadness
# Emotion Distribution: {'sadness': 0.9996688365936279, 'anger': 0.00012090583186363801, 'love': 4.5728465920547023e-05, 'surprise': 5.7777317124418914e-05, 'fear': 4.997264113626443e-05, 'joy': 5.684528514393605e-05}
#
# Text: i came out of the airport that makes me feel irritable uncomfortable and even sadder
# Predicted Emotion: anger
# Emotion Distribution: {'sadness': 0.00011094954970758408, 'anger': 0.999336302280426, 'love': 0.00013470744306687266, 'surprise': 0.00010440851474413648, 'fear': 0.0002505038573872298, 'joy': 6.319852400338277e-05}
#
# Text: i wasnt feeling sociable i really wasnt
# Predicted Emotion: joy
# Emotion Distribution: {'sadness': 6.955757999094203e-05, 'anger': 4.371673276182264e-05, 'love': 0.0001240804704139009, 'surprise': 8.392702875426039e-05, 'fear': 4.199015529593453e-05, 'joy': 0.9996367692947388}
#
# Text: im feeling scared and the rage filled im mad at me
# Predicted Emotion: fear
# Emotion Distribution: {'sadness': 0.00023324351059272885, 'anger': 0.00011123609874630347, 'love': 0.00014909230230841786, 'surprise': 0.00021628165268339217, 'fear': 0.9991254210472107, 'joy': 0.000164707176736556}
#
# Text: i have found myself fighting back as he wakes me from my sleep time and time again feeling the hurt and sting of my own abandonment to my first love
# Predicted Emotion: sadness
# Emotion Distribution: {'sadness': 0.999610960483551, 'anger': 0.00016216468065977097, 'love': 8.284756768262014e-05, 'surprise': 6.09075250395108e-05, 'fear': 4.3639120121952146e-05, 'joy': 3.957681110478006e-05}
#
# Text: i feel defeated that i have to take advil again but i suppose to get the inflammation down inside as well as outside its necessary
# Predicted Emotion: sadness
# Emotion Distribution: {'sadness': 0.9996806383132935, 'anger': 9.891908121062443e-05, 'love': 5.3665829909732565e-05, 'surprise': 6.052773096598685e-05, 'fear': 5.23498238180764e-05, 'joy': 5.400993541115895e-05}
#
# Text: i had that kinda feeling but ignored it
# Predicted Emotion: sadness
# Emotion Distribution: {'sadness': 0.9996424913406372, 'anger': 0.0001255306415259838, 'love': 7.016767631284893e-05, 'surprise': 5.97111284150742e-05, 'fear': 4.016020830022171e-05, 'joy': 6.19576676399447e-05}
#
# Text: i really feel like they were gentle reminders that while god hasnt always promised an easy road he has promised to be with us as we travel the rough ones
# Predicted Emotion: love
# Emotion Distribution: {'sadness': 0.0002245757932541892, 'anger': 0.00031517024035565555, 'love': 0.9986441731452942, 'surprise': 0.00030265518580563366, 'fear': 0.0002458200615365058, 'joy': 0.00026768463430926204}
#
# Text: i dont blame it all to them and im not angry at them infact i feel fairly sympathetic for them
# Predicted Emotion: love
# Emotion Distribution: {'sadness': 0.00025358315906487405, 'anger': 0.0003426668408792466, 'love': 0.9983807802200317, 'surprise': 0.0005386748816817999, 'fear': 0.0002650371170602739, 'joy': 0.0002192098618252203}
#
# Text: i feel tortured delilahlwl am considering i had one the other day about one of my closest friends raping and killing chicks
# Predicted Emotion: fear
# Emotion Distribution: {'sadness': 0.0013956637121737003, 'anger': 0.1479925513267517, 'love': 0.0005410827579908073, 'surprise': 0.000521915964782238, 'fear': 0.8490399122238159, 'joy': 0.0005088999751023948}
#
# Text: i told my fiance how i am feeling so angry and upset
# Predicted Emotion: anger
# Emotion Distribution: {'sadness': 0.0001268374326173216, 'anger': 0.9992328882217407, 'love': 0.00011883101251441985, 'surprise': 0.00011159021960338578, 'fear': 0.00033881471608765423, 'joy': 7.097957859514281e-05}
#
# Text: i can feel its suffering
# Predicted Emotion: sadness
# Emotion Distribution: {'sadness': 0.9996519088745117, 'anger': 0.0001335931447101757, 'love': 6.885494804009795e-05, 'surprise': 5.318729017744772e-05, 'fear': 5.7340501371072605e-05, 'joy': 3.511223621899262e-05}
#
# Text: i just keep feeling like someone is being unkind to me and doing me wrong and then all i can think of doing is to get back at them and the people they are close to
# Predicted Emotion: anger
# Emotion Distribution: {'sadness': 0.0002925914595834911, 'anger': 0.9991218447685242, 'love': 0.0003122748457826674, 'surprise': 0.00012492857058532536, 'fear': 8.633370453026146e-05, 'joy': 6.20406135567464e-05}
#
# Text: im feeling a little cranky negative after this doctors appointment
# Predicted Emotion: anger
# Emotion Distribution: {'sadness': 0.00014282976917456836, 'anger': 0.9993707537651062, 'love': 0.00019017388694919646, 'surprise': 0.0001279867283301428, 'fear': 0.00011353419540682808, 'joy': 5.4748146794736385e-05}
#
# Text: i feel that i am useful to my people and that gives me a great feeling of achievement
# Predicted Emotion: joy
# Emotion Distribution: {'sadness': 6.885667244205251e-05, 'anger': 4.144839840591885e-05, 'love': 0.00013610861788038164, 'surprise': 7.45674260542728e-05, 'fear': 4.002562855021097e-05, 'joy': 0.9996389150619507}
#
# Text: im feeling more comfortable with derby i feel as though i can start to step out my shell
# Predicted Emotion: joy
# Emotion Distribution: {'sadness': 6.0001981182722375e-05, 'anger': 4.086955595994368e-05, 'love': 0.0001197979727294296, 'surprise': 8.410933514824137e-05, 'fear': 5.913357381359674e-05, 'joy': 0.9996360540390015}
#
# Text: i feel all weird when i have to meet w people i text but like dont talk face to face w
# Predicted Emotion: fear
# Emotion Distribution: {'sadness': 0.0008616399136371911, 'anger': 0.0004619346000254154, 'love': 0.0005766222602687776, 'surprise': 0.1353004276752472, 'fear': 0.8621742725372314, 'joy': 0.000625212152954191}
#
# Accuracy: 92.75%

# %%
# !zip -r ./content/emotion_essay_model.zip ./content
# Out:
# 	zip warning: name not matched: ./content
#
# zip error: Nothing to do! (try: zip -r ./content/emotion_essay_model.zip . -i ./content)

# %%
# !zip -r content.zip /content/
# Out:
#   adding: content/ (stored 0%)
#   adding: content/.config/ (stored 0%)
#   adding: content/.config/configurations/ (stored 0%)
#   adding: content/.config/configurations/config_default (deflated 15%)
#   adding: content/.config/gce (stored 0%)
#   adding: content/.config/.last_opt_in_prompt.yaml (stored 0%)
#   adding: content/.config/.last_survey_prompt.yaml (stored 0%)
#   adding: content/.config/default_configs.db (deflated 98%)
#   adding: content/.config/config_sentinel (stored 0%)
#   adding: content/.config/logs/ (stored 0%)
#   adding: content/.config/logs/2024.04.17/ (stored 0%)
#   adding: content/.config/logs/2024.04.17/13.28.43.997536.log (deflated 91%)
#   adding: content/.config/logs/2024.04.17/13.29.19.698756.log (deflated 86%)
#   adding: content/.config/logs/2024.04.17/13.29.27.757827.log (deflated 58%)
#   adding: content/.config/logs/2024.04.17/13.29.38.297557.log (deflated 56%)
#   adding: content/.config/logs/2024.04.17/13.29.37.622123.log (deflated 57%)
#   adding: content/.config/logs/2024.04.17/13.29.09.819054.log (deflated 58%)
#   adding: content/.config/active_config (stored 0%)
#   adding: content/.config/.last_update_check.json (deflated 23%)
#   adding: content/val.txt (deflated 65%)
#   adding: content/train.txt (deflated 65%)
#   adding: content/drive/ (stored 0%)
#   adding: content/drive/MyDrive/ (stored 0%)
#   adding: content/drive/MyDrive/model_save/ (stored 0%)
#   adding: content/drive/MyDrive/model_save/model.safetensors (deflated 7%)
#   adding: content/drive/MyDrive/model_save/tokenizer_config.json (deflated 75%)
#   adding: content/drive/MyDrive/model_save/config.json (deflated 54%)
#   adding: content/drive/MyDrive/model_save/special_tokens_map.json (deflated 42%)
#   adding: content/drive/MyDrive/model_save/vocab.txt (deflated 53%)
#   adding: content/test.txt (deflated 65%)
#   adding: content/sample_data/ (stored 0%)
#   adding: content/sample_data/README.md (deflated 42%)
#   adding: content/sample_data/anscombe.json (deflated 83%)
#   adding: content/sample_data/mnist_test.csv (deflated 88%)
#   adding: content/sample_data/california_housing_train.csv (deflated 79%)
#   adding: content/sample_data/mnist_train_small.csv (deflated 88%)
#   adding: content/sample_data/california_housing_test.csv (deflated 76%)

# %%
from google.colab import files
files.download('new_content.zip')

# %%
# !zip -r model_download.zip /content/ -x "*sample_data*"
# Out:
#   adding: content/ (stored 0%)
#   adding: content/.config/ (stored 0%)
#   adding: content/.config/configurations/ (stored 0%)
#   adding: content/.config/configurations/config_default (deflated 15%)
#   adding: content/.config/gce (stored 0%)
#   adding: content/.config/.last_opt_in_prompt.yaml (stored 0%)
#   adding: content/.config/.last_survey_prompt.yaml (stored 0%)
#   adding: content/.config/default_configs.db (deflated 98%)
#   adding: content/.config/config_sentinel (stored 0%)
#   adding: content/.config/logs/ (stored 0%)
#   adding: content/.config/logs/2024.04.17/ (stored 0%)
#   adding: content/.config/logs/2024.04.17/13.28.43.997536.log (deflated 91%)
#   adding: content/.config/logs/2024.04.17/13.29.19.698756.log (deflated 86%)
#   adding: content/.config/logs/2024.04.17/13.29.27.757827.log (deflated 58%)
#   adding: content/.config/logs/2024.04.17/13.29.38.297557.log (deflated 56%)
#   adding: content/.config/logs/2024.04.17/13.29.37.622123.log (deflated 57%)
#   adding: content/.config/logs/2024.04.17/13.29.09.819054.log (deflated 58%)
#   adding: content/.config/active_config (stored 0%)
#   adding: content/.config/.last_update_check.json (deflated 23%)
#   adding: content/val.txt (deflated 65%)
#   adding: content/content.zip (stored 0%)
#   adding: content/train.txt (deflated 65%)
#   adding: content/drive/ (stored 0%)
#   adding: content/drive/MyDrive/ (stored 0%)
#   adding: content/drive/MyDrive/model_save/ (stored 0%)
#   adding: content/drive/MyDrive/model_save/model.safetensors (deflated 7%)
#   adding: content/drive/MyDrive/model_save/tokenizer_config.json (deflated 75%)
#   adding: content/drive/MyDrive/model_save/config.json (deflated 54%)
#   adding: content/drive/MyDrive/model_save/special_tokens_map.json (deflated 42%)
#   adding: content/drive/MyDrive/model_save/vocab.txt (deflated 53%)
#   adding: content/test.txt (deflated 65%)

# %%
# !zip -r new_content.zip /content/ -x "*sample_data*" "*content.zip*" "*model_downlaod.zip*"
# Out:
#   adding: content/ (stored 0%)
#   adding: content/.config/ (stored 0%)
#   adding: content/.config/configurations/ (stored 0%)
#   adding: content/.config/configurations/config_default (deflated 15%)
#   adding: content/.config/gce (stored 0%)
#   adding: content/.config/.last_opt_in_prompt.yaml (stored 0%)
#   adding: content/.config/.last_survey_prompt.yaml (stored 0%)
#   adding: content/.config/default_configs.db (deflated 98%)
#   adding: content/.config/config_sentinel (stored 0%)
#   adding: content/.config/logs/ (stored 0%)
#   adding: content/.config/logs/2024.04.17/ (stored 0%)
#   adding: content/.config/logs/2024.04.17/13.28.43.997536.log (deflated 91%)
#   adding: content/.config/logs/2024.04.17/13.29.19.698756.log (deflated 86%)
#   adding: content/.config/logs/2024.04.17/13.29.27.757827.log (deflated 58%)
#   adding: content/.config/logs/2024.04.17/13.29.38.297557.log (deflated 56%)
#   adding: content/.config/logs/2024.04.17/13.29.37.622123.log (deflated 57%)
#   adding: content/.config/logs/2024.04.17/13.29.09.819054.log (deflated 58%)
#   adding: content/.config/active_config (stored 0%)
#   adding: content/.config/.last_update_check.json (deflated 23%)
#   adding: content/.ipynb_checkpoints/ (stored 0%)
#   adding: content/val.txt (deflated 65%)
#   adding: content/train.txt (deflated 65%)
#   adding: content/drive/ (stored 0%)
#   adding: content/drive/MyDrive/ (stored 0%)
#   adding: content/drive/MyDrive/model_save/ (stored 0%)
#   adding: content/drive/MyDrive/model_save/model.safetensors (deflated 7%)
#   adding: content/drive/MyDrive/model_save/tokenizer_config.json (deflated 75%)
#   adding: content/drive/MyDrive/model_save/config.json (deflated 54%)
#   adding: content/drive/MyDrive/model_save/special_tokens_map.json (deflated 42%)
#   adding: content/drive/MyDrive/model_save/vocab.txt (deflated 53%)
#   adding: content/test.txt (deflated 65%)

# %%
from google.colab import files
files.download('new_content.zip')

# %%
files.download('/content/drive/MyDrive/model_save/model.safetensors')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp -r /content/drive_n/MyDrive/* /content/drive/MyDrive/

# %%
from google.colab import drive
drive.mount('/content/drive')
